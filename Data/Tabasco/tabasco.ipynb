# %%
import pandas as pd

# %%
# Use tabula to read pdf files.
# http://tabula.technology/

# Upload converted csv file.
tabasco = pd.read_csv('tabasco_tabula_2017.csv', usecols = [0,4,6,7])

# Rename columns.
tabasco.columns = ['agrupacion', 'nombre', 'inicio', 'vencimiento']

# Reorder columns.
tabasco = tabasco[['nombre', 'agrupacion', 'inicio', 'vencimiento']]

# %%
tabasco[20:50]
# Out:
#                            nombre  \
# 20        AMILCAR FLORES SANSORES
# 21          JEILER GARCIA RAMIREZ
# 22        HUMBERTO MOSQUEDA ARCOS
# 23           MAXIMO CUAPIO GUZMAN
# 24  MARIA DEL CARMEN LOPEZ TEJERO
# 25       EVARISTO CASTILLO PIEDRA
# 26        JULIANA MENDEZ SALVADOR
# 27  ERICK DANIEL PERALTA MARTINEZ
# 28             MARIANA KURY PEREZ
# 29    MARIA LUISA GARCIA AVENDAÑO
# 30            CARLOS VERA BERTRUV
# 31        ARISTEO BADILLO CABRERA
# 32      ANA LISBE CASTELLANOS QUE
# 33       FELIPA MARTINEZ OLIVARES
# 34          GILBERTO VERA BERTRUY
# 35       MARIO ARTURO VERA LEZAMA
# 36        FERNANDO CARMONA HUERTA
# 37        MARIO MANDUJANO AREVALO
# 38        ELO3DESEPTIEMBREDEL2O2S
# 39     EL 03 DESEPTIEMBRE DEL2025
# 40      ELES DESEPTIEMBRE DEL2O2S
# 41     ELO3 DE SEPTIEMBRE DEL2O2S
# 42        ELO3DESEPTIEMBREDEL2025
# 43     ELES DE SEPTIEMBRE DEL2O2S
# 44     ELO3 DE SEPIjEMERE DEL2O2S
# 45     ELDa DE SEPTIEMBRE DEL202S
# ...

# %%
tabasco2 = pd.read_csv('tabasco_tabula(2)_2017.csv', error_bad_lines = False)

# Rename columns.
#tabasco1.columns = ['agrupacion', 'nombre', 'inicio', 'vencimiento']

# Reorder columns.
#tabasco1 = tabasco1[['nombre', 'agrupacion', 'inicio', 'vencimiento']]
# Out:
# b'Skipping line 118: expected 5 fields, saw 6\nSkipping line 119: expected 5 fields, saw 6\nSkipping line 120: expected 5 fields, saw 6\nSkipping line 121: expected 5 fields, saw 6\nSkipping line 122: expected 5 fields, saw 6\nSkipping line 123: expected 5 fields, saw 6\nSkipping line 124: expected 5 fields, saw 6\nSkipping line 125: expected 5 fields, saw 6\nSkipping line 126: expected 5 fields, saw 6\nSkipping line 127: expected 5 fields, saw 6\nSkipping line 128: expected 5 fields, saw 6\nSkipping line 129: expected 5 fields, saw 6\nSkipping line 130: expected 5 fields, saw 6\nSkipping line 131: expected 5 fields, saw 6\nSkipping line 132: expected 5 fields, saw 6\nSkipping line 133: expected 5 fields, saw 6\nSkipping line 134: expected 5 fields, saw 6\nSkipping line 135: expected 5 fields, saw 6\nSkipping line 136: expected 5 fields, saw 6\nSkipping line 137: expected 5 fields, saw 6\nSkipping line 138: expected 5 fields, saw 6\nSkipping line 139: expected 5 fields, saw 6\nSkippi
# ...

# %%
tabasco2.head()
# Out:
#    155  \
# 0  155
# 1  155
# 2  155
# 3  155
# 4  155
#
#   UNIÓN DE TRABAJADORES PROPIETARIOS DE AUTOMÓVILES DE ALQUILER DEL MUNICIPIO DE BALANCÁN, TABASCO.  \
# 0  UNIÓN DE TRABAJADORES PROPIETARIOS DE AUTOMÓVI...
# 1  UNIÓN DE TRABAJADORES PROPIETARIOS DE AUTOMÓVI...
# 2  UNIÓN DE TRABAJADORES PROPIETARIOS DE AUTOMÓVI...
# 3  UNIÓN DE TRABAJADORES PROPIETARIOS DE AUTOMÓVI...
# 4  UNIÓN DE TRABAJADORES PROPIETARIOS DE AUTOMÓVI...
#
#          SADY PAZ ESCALANTE      D4DESEPTIEMBREDEL2D15  \
# 0    ANA LUZ MOSQUEDA ARCOS   04 DE SEPTIEMBRE DEL2O15
# 1   BARTOLO FLORES GONZALEZ   04 DE SEPTIEMBRE DEL20IS
# 2       NEIL AGUILAR JUAREZ   04 DE SEPTIEMBRE DEL2OI5
# 3     FERNANDO REYES CASTRO      04DESEPTIEMBREDEL2015
# 4  MONICA MARTINEZ OLIVARES  04 DE SEPTIEMBRE DEL 2015
#
#       ELO3DESEPTIEMBREDEL2O2S
# 0  EL 03 DESEPTIEMBRE DEL2025
# 1   ELES DESEPTIEMBRE DEL2O2S
# 2  ELO3 DE SEPTIEMBRE DEL2O2S
# 3     ELO3DESEPTIEMBREDEL2025
# 4  ELES DE SEPTIEMBRE DEL2O2S
